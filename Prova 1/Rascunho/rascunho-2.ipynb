# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('wine_ap1.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  \
# 0           0    14.23        1.71  2.43               15.6      127.0
# 1           1    13.20        1.78  2.14               11.2      100.0
# 2           2    13.16        2.36  2.67               18.6      101.0
# 3           3    14.37        1.95  2.50               16.8      113.0
# 4           4    13.24         NaN   NaN               21.0      118.0
#
#    total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# 0           2.80        3.06                  0.28             2.29
# 1           2.65        2.76                  0.26             1.28
# 2           2.80        3.24                  0.30             2.81
# 3           3.85        3.49                  0.24             2.18
# 4           2.80        2.69                  0.39             1.82
#
#    color_intensity   hue  od280/od315_of_diluted_wines  proline  y
# ...

# %%
df = df.drop('Unnamed: 0', axis=1)

df.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24         NaN   NaN               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline  y
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
# alcohol                         169 non-null float64
# malic_acid                      167 non-null float64
# ash                             172 non-null float64
# alcalinity_of_ash               169 non-null float64
# magnesium                       165 non-null float64
# total_phenols                   169 non-null float64
# flavanoids                      165 non-null float64
# nonflavanoid_phenols            165 non-null float64
# proanthocyanins                 167 non-null float64
# color_intensity                 171 non-null float64
# hue                             165 non-null float64
# od280/od315_of_diluted_wines    172 non-null float64
# proline                         170 non-null float64
# y                               178 non-null int64
# dtypes: float64(13), int64(1)
# memory usage: 19.5 KB

# %%
df.describe()
# Out:
#           alcohol  malic_acid         ash  alcalinity_of_ash   magnesium  \
# count  169.000000  167.000000  172.000000         169.000000  165.000000
# mean    13.038876    2.345569    2.368837          19.485207   99.478788
# std      0.798573    1.135853    0.272384           3.349212   13.953139
# min     11.030000    0.740000    1.360000          10.600000   70.000000
# 25%     12.370000    1.605000    2.217500          17.200000   88.000000
# 50%     13.050000    1.860000    2.360000          19.500000   98.000000
# 75%     13.710000    3.110000    2.560000          21.500000  107.000000
# max     14.830000    5.800000    3.230000          30.000000  162.000000
#
#        total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# count     169.000000  165.000000            165.000000       167.000000
# mean        2.290414    2.042303              0.358242         1.604132
# std         0.630859    1.002261              0.125455         0.578549
# ...

# %% [markdown]
# ### 1ª questão

# %% [markdown]
# #### Alternativa a)

# %%
#Verificando a média dos elementos de um atributo
df['alcohol'].mean()
# Out:
# 13.038875739644961

# %%
df.isna().sum()
# Out:
# alcohol                          9
# malic_acid                      11
# ash                              6
# alcalinity_of_ash                9
# magnesium                       13
# total_phenols                    9
# flavanoids                      13
# nonflavanoid_phenols            13
# proanthocyanins                 11
# color_intensity                  7
# hue                             13
# od280/od315_of_diluted_wines     6
# proline                          8
# y                                0
# dtype: int64

# %%
df = df.fillna(df.mean())

# %%
df.head()
# Out:
#    alcohol  malic_acid       ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23    1.710000  2.430000               15.6      127.0           2.80
# 1    13.20    1.780000  2.140000               11.2      100.0           2.65
# 2    13.16    2.360000  2.670000               18.6      101.0           2.80
# 3    14.37    1.950000  2.500000               16.8      113.0           3.85
# 4    13.24    2.345569  2.368837               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
# ...

# %%
df['alcohol'].mean()
# Out:
# 13.038875739644965

# %%
df.describe()
# Out:
#           alcohol  malic_acid         ash  alcalinity_of_ash   magnesium  \
# count  178.000000  178.000000  178.000000         178.000000  178.000000
# mean    13.038876    2.345569    2.368837          19.485207   99.478788
# std      0.778005    1.099992    0.267727           3.262952   13.430965
# min     11.030000    0.740000    1.360000          10.600000   70.000000
# 25%     12.370000    1.630000    2.230000          17.425000   89.000000
# 50%     13.044438    1.900000    2.368837          19.485207   98.500000
# 75%     13.677500    3.020000    2.547500          21.500000  106.000000
# max     14.830000    5.800000    3.230000          30.000000  162.000000
#
#        total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# count     178.000000  178.000000            178.000000       178.000000
# mean        2.290414    2.042303              0.358242         1.604132
# std         0.614611    0.964753              0.120760         0.560283
# ...

# %%
#Para cada atributo quantitativo, calcular total, média, desvio padrão, mínimo e máximo
from pandas.api.types import is_numeric_dtype

for col in df.columns :
    if is_numeric_dtype(df[col]):
        print(col)
        print("- Total: " + str(df[col].count()))
        print("- Média: " + str(df[col].mean()))
        print("- Desvio padrão: " + str(df[col].std()))
        print("- Máximo: " + str(df[col].max()))
        print("- Mínimo: " + str(df[col].min()) + "\n")
# Out:
# alcohol
# - Total: 178
# - Média: 13.038875739644965
# - Desvio padrão: 0.7780051500509709
# - Máximo: 14.83
# - Mínimo: 11.03
#
# malic_acid
# - Total: 178
# - Média: 2.3455688622754494
# - Desvio padrão: 1.0999915792129757
# - Máximo: 5.8
# - Mínimo: 0.74
#
# ash
# - Total: 178
# - Média: 2.3688372093023267
# - Desvio padrão: 0.2677270665386744
# - Máximo: 3.23
# - Mínimo: 1.36
#
# alcalinity_of_ash
# - Total: 178
# - Média: 19.485207100591712
# - Desvio padrão: 3.262951609760016
# - Máximo: 30.0
# - Mínimo: 10.6
#
# magnesium
# - Total: 178
# - Média: 99.47878787878788
# - Desvio padrão: 13.430965098946855
# - Máximo: 162.0
# - Mínimo: 70.0
#
# total_phenols
# - Total: 178
# - Média: 2.2904142011834323
# - Desvio padrão: 0.6146105790459826
# - Máximo: 3.88
# - Mínimo: 0.98
#
# flavanoids
# - Total: 178
# - Média: 2.042303030303029
# - Desvio padrão: 0.964752609747203
# - Máximo: 5.08
# - Mínimo: 0.34
#
# nonflavanoid_phenols
# - Total: 178
# - Média: 0.3582424242424244
# ...

# %% [markdown]
# #### Alternativa b)

# %%
df.cov().style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_0c4af5c6_e59e_11e9_ac0b_ff74e6f1b764row0_col0 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_0c4af5c6_e59e_11e9_ac0b_ff74e6f1b764row0_col1 {
#             background-color:  #023c5f;
#             color:  #f1f1f1;
#         }    #T_0c4af5c6_e59e_11e9_ac0b_ff74e6f1b764row0_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_0c4af5c6_e59e_11e9_ac0b_ff74e6f1b764row0_col3 {
#             background-color:  #023e62;
#             color:  #f1f1f1;
#         }    #T_0c4af5c6_e59e_11e9_ac0b_ff74e6f1b764row0_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_0c4af5c6_e59e_11e9_ac0b_ff74e6f1b764row0_col5 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_0c4af5c6_e59e_11e9_ac0b_ff74e6f1b764row0_col6 {
#             background-color:  #fef6fa;
#             color:  #000000;
# ...

# %% [markdown]
# O sinal na covariância indica o tipo de relação que as duas variáveis tem. Um sinal positivo indica que elas movem juntas e um negativo que elas movem em direções opostas. Enquanto a covariância cresce com o poder do relacionamento, ainda é relativamente difícil fazer julgamentos sobre o poder do relacionamento entre as duas variáveis observando a covariância, pois ela não é padronizada.

# %%
(df.cov() > 0).sum()
# Out:
# alcohol                         10
# malic_acid                       7
# ash                             11
# alcalinity_of_ash                6
# magnesium                       10
# total_phenols                    9
# flavanoids                       9
# nonflavanoid_phenols             6
# proanthocyanins                  9
# color_intensity                  9
# hue                              7
# od280/od315_of_diluted_wines     8
# proline                         10
# y                                5
# dtype: int64

# %%
(df.cov() < 0).sum()
# Out:
# alcohol                         4
# malic_acid                      7
# ash                             3
# alcalinity_of_ash               8
# magnesium                       4
# total_phenols                   5
# flavanoids                      5
# nonflavanoid_phenols            8
# proanthocyanins                 5
# color_intensity                 5
# hue                             7
# od280/od315_of_diluted_wines    6
# proline                         4
# y                               9
# dtype: int64

# %%
df.corr().style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_0c72a7c4_e59e_11e9_ac0b_ff74e6f1b764row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0c72a7c4_e59e_11e9_ac0b_ff74e6f1b764row0_col1 {
#             background-color:  #a1bbda;
#             color:  #000000;
#         }    #T_0c72a7c4_e59e_11e9_ac0b_ff74e6f1b764row0_col2 {
#             background-color:  #d1d2e6;
#             color:  #000000;
#         }    #T_0c72a7c4_e59e_11e9_ac0b_ff74e6f1b764row0_col3 {
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }    #T_0c72a7c4_e59e_11e9_ac0b_ff74e6f1b764row0_col4 {
#             background-color:  #a1bbda;
#             color:  #000000;
#         }    #T_0c72a7c4_e59e_11e9_ac0b_ff74e6f1b764row0_col5 {
#             background-color:  #5a9ec9;
#             color:  #000000;
#         }    #T_0c72a7c4_e59e_11e9_ac0b_ff74e6f1b764row0_col6 {
#             background-color:  #569dc8;
#             color:  #000000;
# ...

# %% [markdown]
# A correlação nunca pode ser maior do que 1 ou menor do que menos 1. Uma correlação próxima a zero indica que as duas variáveis não estão relacionadas. Uma correlação positiva indica que as duas variáveis movem juntas, e a relação é forte quanto mais a correlação se aproxima de um. Uma correlação negativa indica que as duas variáveis movem-se em direções opostas, e que a relação também fica mais forte quanto mais próxima de menos 1 a correlção ficar. Duas variáveis que estão perfeitamente correlacionadas positivamente (r=1) movem-se essencialmente em perfeita proporção na mesma direção, enquanto dois conjuntos que estão perfeitamente correlacionados negativamente movem-se em perfeita proporção em direções opostas.

# %%
(df.corr() > 0.5).sum()-1
# Out:
# alcohol                         2
# malic_acid                      0
# ash                             0
# alcalinity_of_ash               1
# magnesium                       0
# total_phenols                   3
# flavanoids                      4
# nonflavanoid_phenols            0
# proanthocyanins                 2
# color_intensity                 1
# hue                             2
# od280/od315_of_diluted_wines    3
# proline                         1
# y                               1
# dtype: int64

# %%
(df.corr() < (-0.5)).sum()
# Out:
# alcohol                         0
# malic_acid                      1
# ash                             0
# alcalinity_of_ash               0
# magnesium                       0
# total_phenols                   1
# flavanoids                      2
# nonflavanoid_phenols            1
# proanthocyanins                 0
# color_intensity                 0
# hue                             2
# od280/od315_of_diluted_wines    1
# proline                         1
# y                               5
# dtype: int64

# %% [markdown]
# #### Alternativa c)

# %%
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC

# %%
X = df.values[:, :-1]
y = df.values[:, -1]

# %%
X.shape
# Out:
# (178, 13)

# %%
y.shape
# Out:
# (178,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42, stratify=y)

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((133, 13), (133,), (45, 13), (45,))

# %%
plt.plot(X_train);

# %%
plt.plot(X_test);

# %%
scaler = preprocessing.StandardScaler()

scaler.fit(X_train)

X_train_scaler = scaler.transform(X_train)
X_test_scaler = scaler.transform(X_test)

# %%
plt.plot(X_train_scaler);

# %%
plt.plot(X_test_scaler);

# %%
clf_scaler = SVC(random_state=42).fit(X_train_scaler, y_train)
clf_scaler.score(X_test_scaler, y_test)
# Out:
# 0.9555555555555556

# %% [markdown]
# ### 2ª Questão

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt = DecisionTreeClassifier(random_state=42)
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=42, splitter='best')

# %%
from sklearn.metrics import accuracy_score

# %%
y_pred_dt_train = dt.predict(X_train)
accuracy_score(y_train, y_pred_dt_train)
# Out:
# 1.0

# %%
y_pred_dt_test = dt.predict(X_test)
accuracy_score(y_test, y_pred_dt_test)
# Out:
# 0.8666666666666667

# %%
y_pred_dt_train_scl = dt.predict(X_train_scaler)
accuracy_score(y_train, y_pred_dt_train_scl)
# Out:
# 0.40601503759398494

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier()

knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')

# %%
y_pred_knn_train = knn.predict(X_train)
accuracy_score(y_train, y_pred_knn_train)
# Out:
# 0.7819548872180451

# %%
y_pred_knn_test = knn.predict(X_test)
accuracy_score(y_test, y_pred_knn_test)
# Out:
# 0.6444444444444445

# %% [markdown]
# ### 3ª Questão

# %%
from sklearn.metrics import confusion_matrix as cf

# %%
def accuracy(y_true, y_pred) :
    cm = cf(y_true, y_pred)
    return np.sum(np.diagonal(cm))/np.sum(cm)

# %%
def precision(y_true, y_pred) :
    cm = cf(y_true, y_pred, labels=np.unique(y))
    pond = np.unique(y, return_counts=True)[1]
    pre = []
    for i in range(cm.shape[0]) :
        pre.append((pond[i]*cm[i, i])/np.sum(c[:, i]))
    return np.sum(pre)/np.sum(pond)

# %%
def recall(y_true, y_pred) :
    cm = cf(y_true, y_pred, labels=np.unique(y))
    pond = np.unique(y, return_counts=True)[1]
    pre = []
    for i in range(cm.shape[0]) :
        pre.append((pond[i]*cm[i, i])/np.sum(cm[i]))
    return np.sum(pre)/np.sum(pond)

# %%
def f1_measure(y_true, y_pred) :
    recall = recall(y_true, y_pred)
    precision = precision(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall))

# %%
accKNN = []
accDTC = []

precKNN = []
precDTC = []

recKNN = []
recDTC = []

f1KNN = []
f1DTC = []

# %%
y_pred_dt_train_scl = dt.predict(X_train_scaler)
y_pred_dt_test_scl = dt.predict(X_test_scaler)

y_pred_knn_train_scl = knn.predict(X_train_scaler)
y_pred_knn_test_scl = knn.predict(X_test_scaler)

# %%
#Acurácias DTC
accDTC.append(accuracy(y_train, y_pred_dt_train))
accDTC.append(accuracy(y_test, y_pred_dt_test))
accDTC.append(accuracy(y_train, y_pred_dt_train_scl))
accDTC.append(accuracy(y_test, y_pred_dt_test_scl))

# %%
accDTCDict = {}
accDTCDict = {'Acurácia do treino: ' : accDTC[0], 'Acurácia de teste: ' : accDTC[1],
              'Acurácia de treino padronizado: ' : accDTC[2], 'Acurácia de teste padronizado: ' : accDTC[3]}

# %%
accDTCDict
# Out:
# {'Acurácia do treino: ': 1.0,
#  'Acurácia de teste: ': 0.8666666666666667,
#  'Acurácia de treino padronizado: ': 0.40601503759398494,
#  'Acurácia de teste padronizado: ': 0.37777777777777777}

# %%
def accuracy_score(y, y_pred):
    cm = confusion_matrix(y, y_pred)
    return np.sum(np.diagonal(cm))/np.sum(cm)

def precision_score(y, y_p):
    cm = confusion_matrix(y, y_p, labels=np.unique(y))
    pond = np.unique(y, return_counts=True)[1]
    pre = []
    for i in range(cm.shape[0]): 
        pre.append((pond[i] * cm[i,i]) / np.sum(cm[:,i]))
    return np.sum(pre)/np.sum(pond)

def recall_score(y, y_p):
    cm = confusion_matrix(y, y_p, labels=np.unique(y))
    pond = np.unique(y, return_counts=True)[1]
    pre = []
    for i in range(cm.shape[0]): 
        pre.append((pond[i] * cm[i,i]) / np.sum(cm[i]))
    return np.sum(pre)/np.sum(pond)

def f1_measure_score(y, y_p):
    recall = recall_score(y, y_p)
    precision = precision_score(y, y_p)
    return 2 * ((precision * recall) / (precision + recall))

# %% [markdown]
# ### 4ª Questão

# %%
from sklearn.cluster import KMeans

# %%
inertias = []

for k in range(1, 10, 2) :
    model = KMeans(n_clusters=k)
    model.fit(X)
    inertias.append(model.inertia_)

# %%
plt.plot(range(1, 10, 2), inertias, marker='o');

# %% [markdown]
# A técnica acima é chamada de cotovelo, podemos perceber que a partir do k=3, o modelo permanence com a inercia similar, ou seja, significa que os centroids não mudam muito de poisição, portanto, é considerado que este pode ser a melhor configuração de número de clusters.
